# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
g = np.loadtxt("g.dat")
plt.plot(g)

# %%
S = np.loadtxt("S.dat")
plt.plot(S)

# %%
S[S<0]
# Out:
# array([-16.9632])

# %%
S[S<0]
# Out:
# array([-16.9632])
